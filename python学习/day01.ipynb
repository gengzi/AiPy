# %%
print("hello world")

def hello():
    print("hello world")
    print("hello again")
    print("hello again")
# Out:
# hello world

# %%
def get_evas(nums):
    return [num for num in nums if num % 2 == 0]

# %%
from abc import ABC,abstractmethod

class DataProcessor(ABC):
    @abstractmethod
    def process(self,data):
        pass

# %%
pip install fastapi uvicorn
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Collecting fastapi
#   Downloading fastapi-0.128.0-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic>=2.7.0 (from fastapi)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/gengzi/anaconda3/envs/env-embedding/lib/python3.12/site-packages (from fastapi) (4.15.0)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/gengzi/anaconda3/envs/env-embedding/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /home/gengzi/anaconda3/envs/env-embedding/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/gengzi/anaconda3/envs/env-embedding/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (1.3.1)
# Collecting click>=7.0 (from uvicorn)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: h11>=0.8 in /home/gengzi/anaconda3/envs/env-embedding/lib/python3.12/site-packages (from uvicorn) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.0->fastapi)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.7.0->fastapi)
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.7.0->fastapi)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading fastapi-0.128.0-py3-none-any.whl (103 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.3 MB/s  0:00:00m eta 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, click, annotated-types, annotated-doc, uvicorn, starlette, pydantic, fastapi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [fastapi]m8/9 [fastapi]e]
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 click-8.3.1 fastapi-0.128.0 pydantic-2.12.5 pydantic-core-2.41.5 starlette-0.50.0 typing-inspection-0.4.2 uvicorn-0.40.0
# Note: you may need to restart the kernel to use updated packages.
