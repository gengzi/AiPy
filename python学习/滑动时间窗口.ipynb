# %%
## 滑动时间窗口


# class SlidingWindow:

    # ## 定义一个环形数组
    # def __init__(self, size):
    #     self.size = size
    #     self.data = [None] * size
    #     self.start = 0
    #     self.end = 0


## 定义一个环形数组，分为两格子，前一个500ms的数据，后一个500ms的数据
arr = int[2];

## 1000ms / 500ms =  2 % 2 = 0
def add(val):
  # 入槽
    i = val / 500 % 2;
    if(i == 0):
        arr[0] = 0;
    else:
        arr[1] = 0;
    arr[i] = arr[i]+1;
    if(arr[0]+arr[1] > 1000):
        print("无法执行");
    else:
        print("可以执行");
